# %% [markdown]
# # Modeling Workflow for Biochar Application in Brazil
#
# This notebook outlines the modeling workflow for identifying high-potential areas for biochar application across Brazil. The workflow includes data loading, preprocessing, suitability analysis, risk assessment, and visualization.

# %%
# Import necessary libraries
import pandas as pd
import geopandas as gpd
from src.data.loader import load_data
from src.data.preprocessing import preprocess_data
from src.analysis.suitability import calculate_suitability
from src.analysis.risk_assessment import assess_risk
from src.visualization.plots import plot_suitability
from src.visualization.map_renderer import render_map

# Load the data
data = load_data('data/raw/soil_data.csv')

# Preprocess the data
cleaned_data = preprocess_data(data)

# Calculate suitability scores
suitability_scores = calculate_suitability(cleaned_data)

# Assess risks associated with biochar application
risk_scores = assess_risk(cleaned_data)

# Combine suitability and risk scores for final analysis
final_scores = suitability_scores.merge(risk_scores, on='location_id')

# Visualize the results
plot_suitability(final_scores)
render_map(final_scores)

# %% [markdown]
# ## Conclusion
#
# This notebook provides a structured approach to modeling the potential for biochar application in Brazil. The results can guide decision-making for sustainable land management.
